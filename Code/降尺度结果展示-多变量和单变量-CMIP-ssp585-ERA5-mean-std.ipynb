# %%
import Auto_paint_self
slp_model,lon1,lat1,levels1,latlow1,lattop1,lonleft1,lonright1,times1=Auto_paint_self.open_data_nc('one',r'E:\Dr_Research\result\CMIP_slp_predict_era5_mean_std_ssp585_new.nc','slp','yes','time','2015-01-02-06','2099-12-30-18','yes','longitude','yes','latitude',-5.0,52.5,93.0,186.5,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
g250_model,lon1,lat1,levels1,latlow1,lattop1,lonleft1,lonright1,times1=Auto_paint_self.open_data_nc('one',r'E:\Dr_Research\result\CMIP_z300_predict_era5_mean_std_ssp585_new.nc','z300','yes','time','2015-01-02-06','2099-12-30-18','yes','longitude','yes','latitude',-5.0,52.5,93.0,186.5,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
g500_model,lon1,lat1,levels1,latlow1,lattop1,lonleft1,lonright1,times1=Auto_paint_self.open_data_nc('one',r'E:\Dr_Research\result\CMIP_z500_predict_era5_mean_std_ssp585_new.nc','z500','yes','time','2015-01-02-06','2099-12-30-18','yes','longitude','yes','latitude',-5.0,52.5,93.0,186.5,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
u10_model,lon1,lat1,levels1,latlow1,lattop1,lonleft1,lonright1,times1=Auto_paint_self.open_data_nc('one',r'E:\Dr_Research\result\CMIP_u10_predict_era5_mean_std_ssp585_new.nc','u10','yes','time','2015-01-02-06','2099-12-30-18','yes','longitude','yes','latitude',-5.0,52.5,93.0,186.5,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
v10_model,lon1,lat1,levels1,latlow1,lattop1,lonleft1,lonright1,times1=Auto_paint_self.open_data_nc('one',r'E:\Dr_Research\result\CMIP_v10_predict_era5_mean_std_ssp585_new.nc','v10','yes','time','2015-01-02-06','2099-12-30-18','yes','longitude','yes','latitude',-5.0,52.5,93.0,186.5,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
u10_org,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'G:\CMIP\6hour\CNRM-CM6-1-HR\ssp585\uas\uas_6hr_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr.nc','uas','yes','time','2015-01-01-10-30','2099-12-31-22-30','yes','lon','yes','lat',-5.0,53.0,93.0,187.0,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
v10_org,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'G:\CMIP\6hour\CNRM-CM6-1-HR\ssp585\vas\vas_6hr_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr.nc','vas','yes','time','2015-01-01-10-30','2099-12-31-22-30','yes','lon','yes','lat',-5.0,53.0,93.0,187.0,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
slp_org,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'G:\CMIP\6hour\CNRM-CM6-1-HR\ssp585\psl\psl_6hrPlevPt_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr.nc','psl','yes','time','2015-01-01-06','2099-12-31-18','yes','lon','yes','lat',-5.0,53.0,93.0,187.0,0.5,0.5,'no','no',None,None,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
g250_org,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'G:\CMIP\6hour\CNRM-CM6-1-HR\ssp585\zg\zg_6hrPlevPt_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr.nc','zg','yes','time','2015-01-01-06','2099-12-31-18','yes','lon','yes','lat',-5.0,53.0,93.0,187.0,0.5,0.5,'no','yes','plev',25000,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')
g500_org,lon,lat,levels,latlow,lattop,lonleft,lonright,times=Auto_paint_self.open_data_nc('one',r'G:\CMIP\6hour\CNRM-CM6-1-HR\ssp585\zg\zg_6hrPlevPt_CNRM-CM6-1-HR_ssp585_r1i1p1f2_gr.nc','zg','yes','time','2015-01-01-06','2099-12-31-18','yes','lon','yes','lat',-5.0,53.0,93.0,187.0,0.5,0.5,'no','yes','plev',50000,changeresolution=1,timespace=1,ifchange_west_east='no',ifinterpolate='no')

# %%
slp_org=slp_org[:,::-1,:]
g250_org=g250_org[:,::-1,:]*9.80665
g500_org=g500_org[:,::-1,:]*9.80665
u10_org=u10_org[:,::-1,:]
v10_org=v10_org[:,::-1,:]

# %%
slp_org=slp_org[4:-4,:-1,:-1]
g250_org=g250_org[4:-4,:-1,:-1]
g500_org=g500_org[4:-4,:-1,:-1]
u10_org=u10_org[4:-4,:-1,:-1]
v10_org=v10_org[4:-4,:-1,:-1]

# %%
import numpy as np
slp_org=(slp_org-np.nanmean(slp_org,axis=0))/np.nanstd(slp_org,axis=0)
g250_org=(g250_org-np.nanmean(g250_org,axis=0))/np.nanstd(g250_org,axis=0)
g500_org=(g500_org-np.nanmean(g500_org,axis=0))/np.nanstd(g500_org,axis=0)
u10_org=(u10_org-np.nanmean(u10_org,axis=0))/np.nanstd(u10_org,axis=0)
v10_org=(v10_org-np.nanmean(v10_org,axis=0))/np.nanstd(v10_org,axis=0)

slp_model=(slp_model-np.nanmean(slp_model,axis=0))/np.nanstd(slp_model,axis=0)
g250_model=(g250_model-np.nanmean(g250_model,axis=0))/np.nanstd(g250_model,axis=0)
g500_model=(g500_model-np.nanmean(g500_model,axis=0))/np.nanstd(g500_model,axis=0)
u10_model=(u10_model-np.nanmean(u10_model,axis=0))/np.nanstd(u10_model,axis=0)
v10_model=(v10_model-np.nanmean(v10_model,axis=0))/np.nanstd(v10_model,axis=0)

# %%
print(slp_org.shape,slp_model.shape)
# Out:
# (124175, 116, 188) (124175, 116, 188)

# %%
import tensorflow as tf
from sklearn.metrics import mean_squared_error
import numpy as np
mse_slp=np.zeros((slp_org.shape[1],slp_org.shape[2]))
mse_g250=np.zeros((slp_org.shape[1],slp_org.shape[2]))
mse_g500=np.zeros((slp_org.shape[1],slp_org.shape[2]))
mse_u10=np.zeros((slp_org.shape[1],slp_org.shape[2]))
mse_v10=np.zeros((slp_org.shape[1],slp_org.shape[2]))
pearson_slp=np.zeros((slp_org.shape[1],slp_org.shape[2]))
pearson_g250=np.zeros((slp_org.shape[1],slp_org.shape[2]))
pearson_g500=np.zeros((slp_org.shape[1],slp_org.shape[2]))
pearson_u10=np.zeros((slp_org.shape[1],slp_org.shape[2]))
pearson_v10=np.zeros((slp_org.shape[1],slp_org.shape[2]))

# %%
slp_model=np.nan_to_num(slp_model,nan=0)
g250_model=np.nan_to_num(g250_model,nan=0)
g500_model=np.nan_to_num(g500_model,nan=0)
u10_model=np.nan_to_num(u10_model,nan=0)
v10_model=np.nan_to_num(v10_model,nan=0)
slp_org=np.nan_to_num(slp_org,nan=0)
g250_org=np.nan_to_num(g250_org,nan=0)
g500_org=np.nan_to_num(g500_org,nan=0)
u10_org=np.nan_to_num(u10_org,nan=0)
v10_org=np.nan_to_num(v10_org,nan=0)
from tqdm import tqdm
from scipy.stats import pearsonr
with tf.device('/cpu:0'):
    psnr_slp=tf.image.psnr(np.array(slp_model,dtype='float32'),np.array(slp_org,dtype='float32'),max_val=(np.nanmax(np.array(slp_org,dtype='float32'))-np.nanmin(np.array(slp_org,dtype='float32'))))
    ssim_slp=tf.image.ssim(np.array(slp_model,dtype='float32'),np.array(slp_org,dtype='float32'),max_val=(np.nanmax(np.array(slp_org,dtype='float32'))-np.nanmin(np.array(slp_org,dtype='float32'))))
    psnr_g250=tf.image.psnr(np.array(g250_model,dtype='float32'),np.array(g250_org,dtype='float32'),max_val=(np.nanmax(np.array(g250_org,dtype='float32'))-np.nanmin(np.array(g250_org,dtype='float32'))))
    ssim_g250=tf.image.ssim(np.array(g250_model,dtype='float32'),np.array(g250_org,dtype='float32'),max_val=(np.nanmax(np.array(g250_org,dtype='float32'))-np.nanmin(np.array(g250_org,dtype='float32'))))
    psnr_g500=tf.image.psnr(np.array(g500_model,dtype='float32'),np.array(g500_org,dtype='float32'),max_val=(np.nanmax(np.array(g500_org,dtype='float32'))-np.nanmin(np.array(g500_org,dtype='float32'))))
    ssim_g500=tf.image.ssim(np.array(g500_model,dtype='float32'),np.array(g500_org,dtype='float32'),max_val=(np.nanmax(np.array(g500_org,dtype='float32'))-np.nanmin(np.array(g500_org,dtype='float32'))))
    psnr_u10=tf.image.psnr(np.array(u10_model,dtype='float32'),np.array(u10_org,dtype='float32'),max_val=(np.nanmax(np.array(u10_org,dtype='float32'))-np.nanmin(np.array(u10_org,dtype='float32'))))
    ssim_u10=tf.image.ssim(np.array(u10_model,dtype='float32'),np.array(u10_org,dtype='float32'),max_val=(np.nanmax(np.array(u10_org,dtype='float32'))-np.nanmin(np.array(u10_org,dtype='float32'))))
    psnr_v10=tf.image.psnr(np.array(v10_model,dtype='float32'),np.array(v10_org,dtype='float32'),max_val=(np.nanmax(np.array(v10_org,dtype='float32'))-np.nanmin(np.array(v10_org,dtype='float32'))))
    ssim_v10=tf.image.ssim(np.array(v10_model,dtype='float32'),np.array(v10_org,dtype='float32'),max_val=(np.nanmax(np.array(v10_org,dtype='float32'))-np.nanmin(np.array(v10_org,dtype='float32'))))
    for i in range(slp_org.shape[1]):
        for j in range(slp_org.shape[2]):
            mse_slp[i,j]=mean_squared_error(slp_org[:,i,j],slp_model[:,i,j])
            mse_g250[i,j]=mean_squared_error(g250_org[:,i,j],g250_model[:,i,j])
            mse_g500[i,j]=mean_squared_error(g500_org[:,i,j],g500_model[:,i,j])
            mse_u10[i,j]=mean_squared_error(u10_org[:,i,j],u10_model[:,i,j])
            mse_v10[i,j]=mean_squared_error(v10_org[:,i,j],v10_model[:,i,j])
            pearson_slp[i,j],_=pearsonr(slp_org[:,i,j],slp_model[:,i,j])
            pearson_g250[i,j],_=pearsonr(g250_org[:,i,j],g250_model[:,i,j])
            pearson_g500[i,j],_=pearsonr(g500_org[:,i,j],g500_model[:,i,j])
            pearson_u10[i,j],_=pearsonr(u10_org[:,i,j],u10_model[:,i,j])
            pearson_v10[i,j],_=pearsonr(v10_org[:,i,j],v10_model[:,i,j])       
print((np.nanmean(psnr_slp)+np.nanmean(psnr_g250)+np.nanmean(psnr_g500)+np.nanmean(psnr_u10)+np.nanmean(psnr_v10))/5.0)
print((np.nanmean(ssim_slp)+np.nanmean(ssim_g250)+np.nanmean(ssim_g500)+np.nanmean(ssim_u10)+np.nanmean(ssim_v10))/5.0)
print((np.nanmean(mse_slp)+np.nanmean(mse_g250)+np.nanmean(mse_g500)+np.nanmean(mse_u10)+np.nanmean(mse_v10))/5.0)
print((np.nanmean(pearson_slp)+np.nanmean(pearson_g250)+np.nanmean(pearson_g500)+np.nanmean(pearson_u10)+np.nanmean(pearson_v10))/5.0)
# Out:
# 34.169735717773435
# 0.7664415836334229
# 0.2039502996149105
# 0.9020414708989108

# %%
print(np.nanmean(psnr_slp),np.nanmean(psnr_g250),np.nanmean(psnr_g500),np.nanmean(psnr_u10),np.nanmean(psnr_v10))
print(np.nanmean(ssim_slp),np.nanmean(ssim_g250),np.nanmean(ssim_g500),np.nanmean(ssim_u10),np.nanmean(ssim_v10))
print(np.nanmean(mse_slp),np.nanmean(mse_g250),np.nanmean(mse_g500),np.nanmean(mse_u10),np.nanmean(mse_v10))
print(np.nanmean(pearson_slp),np.nanmean(pearson_g250),np.nanmean(pearson_g500),np.nanmean(pearson_u10),np.nanmean(pearson_v10))
# Out:
# 36.516644 30.16632 33.314285 35.14664 35.70479
# 0.80686766 0.6916866 0.76041526 0.7999737 0.7732647
# 0.24110878929680168 0.07338495640527273 0.15002756057329722 0.23862287915020697 0.316607312648974
# 0.8870548221214499 0.9694249905086904 0.93133964497639 0.8806898706623993 0.8416980262256242
